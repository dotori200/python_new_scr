# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/pia222sk20/python/refs/heads/main/data/movies_train.csv'
df = pd.read_csv(url)
col_discription = ['제목','배급사','장르','개봉일','상영시간','상영등급','감독이름','감독 이전작품 평균 관객수', '감독 이전 작품수', '스탭수', '주연배우수', '관객수']
df.columns
pd.DataFrame(col_discription,index=df.columns)
# Out:
#                              0
# title                       제목
# distributor                배급사
# genre                       장르
# release_time               개봉일
# time                      상영시간
# screening_rat             상영등급
# director                  감독이름
# dir_prev_bfnum  감독 이전작품 평균 관객수
# dir_prev_num         감독 이전 작품수
# num_staff                  스탭수
# num_actor                주연배우수
# box_off_num                관객수

# %%
# df.isna()
df.isnull().sum().sum()
# Out:
# np.int64(330)

# %%
df[df.isnull().any(axis=1)]
df.drop(columns=['distributor'])
# Out:
#          title genre release_time  time screening_rat director  \
# 0       개들의 전쟁    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...   ...          ...   ...           ...      ...
# 595         해무   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린    액션   2013-01-30   120       15세 관람가      류승완
#
#      dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0               NaN             0         91          2        23398
# 1        1161602.50             2        387          3      7072501
# ...

# %%
df[df.isna()]
# Out:
#     title distributor genre release_time  time screening_rat director  \
# 0     NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 1     NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 2     NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 3     NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 4     NaN         NaN   NaN          NaN   NaN           NaN      NaN
# ..    ...         ...   ...          ...   ...           ...      ...
# 595   NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 596   NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 597   NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 598   NaN         NaN   NaN          NaN   NaN           NaN      NaN
# 599   NaN         NaN   NaN          NaN   NaN           NaN      NaN
#
#      dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
sn.boxplot(data=df)
# Out:
# <Axes: >

# %%
# 관객수 box_off_num과 높은 상관관계를 가지는 변수를 찾아라.

# %% [markdown]
# 상관계수
# ---------
# 상관계수 : 두 변수간의 관계강도와 방향을 측정
# 피어슨 상관계수 : 선형관계를 측정, 데이터가 정규분포를 따르고 선형일 때
# 스피어만 상관계수 : 순위기반, 비선형관계나 또는 순서 데이터 (예: 순위, 크기)
# ---------
# 피어슨 상관계수
# ![image.png](attachment:image.png)
# 1. 각 변수의 평균 계산
# 2. 각 데이터 포인트에서 평균을 뺀 값을 계산 (편차)
# 3. 편차들의 곱의 합 계산 (공분산의 분자 계산)
# 4. 각 편차의 제곱합 계산
# 5. 분자 / (분모의 제곱근) 계산

# %% [markdown]
# 스피어만 상관계수
# ---------
# 두 변수의
# ![image-2.png](attachment:image-2.png)
# 1.

# %%
# x=온도, y=아이스크림 판매량
import numpy as np
X = np.array([20,25,30,36,40])
Y = np.array([10,15,20,25,30])
x_mean = X.mean()
y_mean = Y.mean()
x_ = X - x_mean
y_ = Y - y_mean 
# 편차 곱 합
(x_ * y_).sum()
# 각 변수의 편차의 제곱 합
(x_**2).sum() , (y_**2).sum()
# 분모
(x_**2).sum()*(y_**2).sum()
np.sqrt((x_**2).sum()*(y_**2).sum())
(x_ * y_).sum()/np.sqrt((x_**2).sum()*(y_**2).sum())
# Out:
# np.float64(0.9986570737346456)
